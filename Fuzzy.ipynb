# %%
from thefuzz import fuzz,process

import pandas as pd

# %%
popular=pd.read_csv("popular.csv")

# %%
def search_seq(seq):
    names=list(popular["Book-Title"])
    ret=[]
    for i in process.extract(seq,names):
        if(i[1]>=80):
            ret.append(i[0])
    return ret

# %%
search("Black")
# Out:
# ['Black and Blue',
#  'Black Notice',
#  'Key of Light (Key Trilogy (Paperback))',
#  'Sea Swept (Quinn Brothers (Paperback))',
#  'Inner Harbor (Quinn Brothers (Paperback))']

# %%
seq="Black"
names_list=search_seq(seq)
cols=popular.columns[2:]
print(cols)
final_df=pd.DataFrame(columns=cols)
print(final_df.columns)
print(final_df)
for i in names_list:
    if(popular[popular["Book-Title"]==i].shape[0]==1):
        print(list(popular[popular["Book-Title"]==i].iloc[0,2:].values))

        final_df.loc[len(final_df.index)]=list(popular[popular["Book-Title"]==i].iloc[0,2:].values)
        # print(final_df)
print(final_df)
# Out:
# Index(['ISBN', 'Book-Rating', 'Book-Title', 'Book-Author',
#        'Year-Of-Publication', 'Publisher', 'Image-URL-S', 'Image-URL-M',
#        'Image-URL-L', 'Content'],
#       dtype='object')
# Index(['ISBN', 'Book-Rating', 'Book-Title', 'Book-Author',
#        'Year-Of-Publication', 'Publisher', 'Image-URL-S', 'Image-URL-M',
#        'Image-URL-L', 'Content'],
#       dtype='object')
# Empty DataFrame
# Columns: [ISBN, Book-Rating, Book-Title, Book-Author, Year-Of-Publication, Publisher, Image-URL-S, Image-URL-M, Image-URL-L, Content]
# Index: []
# ...

# %%
final_df
# Out:
#          ISBN  Book-Rating                                 Book-Title  \
# 0  0440226104     1.484536                             Black and Blue
# 1  0425175405     1.116279                               Black Notice
# 2  051513628X     2.294118     Key of Light (Key Trilogy (Paperback))
# 3  0515121843     2.033333     Sea Swept (Quinn Brothers (Paperback))
# 4  0515124214     1.813559  Inner Harbor (Quinn Brothers (Paperback))
#
#                  Book-Author  Year-Of-Publication                 Publisher  \
# 0              ANNA QUINDLEN                 1999                      Dell
# 1  Patricia Daniels Cornwell                 2000  Berkley Publishing Group
# 2               Nora Roberts                 2003                Jove Books
# 3               Nora Roberts                 2001                Jove Books
# 4               Nora Roberts                 2001                Jove Books
#
#                                          Image-URL-S  \
# ...
